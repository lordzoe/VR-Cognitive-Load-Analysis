csv
# Cleaned data saved to C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Raw_EyeTrackingData\EyeTrackingData_Participant76_2024_01_30_14_34_40.csv
# Cleaned data saved to C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Raw_EyeTrackingData\EyeTrackingData_Participant77_2024_01_30_16_37_18.csv
# Cleaned data saved to C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Raw_EyeTrackingData\EyeTrackingData_Participant78_2024_01_30_18_03_07.csv
# Cleaned data saved to C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Raw_EyeTrackingData\EyeTrackingData_Participant79_2024_01_31_18_03_52.csv
# Cleaned data saved to C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Raw_EyeTrackingData\EyeTrackingData_Participant80_2024_02_02_13_04_47.csv
# Cleaned data saved to C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Raw_EyeTrackingData\EyeTrackingData_Participant81_2024_02_02_14_11_58.csv

# %% [markdown]
# ### Calculate Validity BitMask

# %%
def gaze_origin_valid(x, y, z):
    return not np.isnan(x) and not np.isnan(y) and not np.isnan(z)

def gaze_direction_valid(x, y, z):
    norm = np.sqrt(x**2 + y**2 + z**2)
    return norm > 0 and not np.isnan(norm)

def pupil_diameter_valid(diameter):
    return diameter > 0 and not np.isnan(diameter)

def eye_openness_valid(openness):
    return 0 <= openness <= 1

# Map validity checks to bitmask positions (excluding pupil position)
validity_map = {
    'SINGLE_EYE_DATA_GAZE_ORIGIN_VALIDITY': 0,
    'SINGLE_EYE_DATA_GAZE_DIRECTION_VALIDITY': 1,
    'SINGLE_EYE_DATA_PUPIL_DIAMETER_VALIDITY': 2,
    'SINGLE_EYE_DATA_EYE_OPENNESS_VALIDITY': 3,
}

raw_folder = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Raw_EyeTrackingData"
filtered_folder = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Filtered_EyeTrackingData"

os.makedirs(filtered_folder, exist_ok=True)

for file_name in os.listdir(raw_folder):
    if file_name.endswith(".csv"):
        file_path = os.path.join(raw_folder, file_name)
        df = pd.read_csv(file_path)
    
        df['LeftEye_BitMask'] = 0
        df['RightEye_BitMask'] = 0

        # Calculate bitmask values
        for index, row in df.iterrows():
            left_bitmask = 0
            right_bitmask = 0

            # Left eye validity checks
            if gaze_origin_valid(row['LeftGazeOriginX'], row['LeftGazeOriginY'], row['LeftGazeOriginZ']):
                left_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_GAZE_ORIGIN_VALIDITY'])
            if gaze_direction_valid(row['LeftGazeX'], row['LeftGazeY'], row['LeftGazeZ']):
                left_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_GAZE_DIRECTION_VALIDITY'])
            if pupil_diameter_valid(row['LeftPupilDiameter']):
                left_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_PUPIL_DIAMETER_VALIDITY'])
            if eye_openness_valid(row['LeftEyeOpenness']):
                left_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_EYE_OPENNESS_VALIDITY'])

            # Right eye validity checks
            if gaze_origin_valid(row['RightGazeOriginX'], row['RightGazeOriginY'], row['RightGazeOriginZ']):
                right_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_GAZE_ORIGIN_VALIDITY'])
            if gaze_direction_valid(row['RightGazeX'], row['RightGazeY'], row['RightGazeZ']):
                right_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_GAZE_DIRECTION_VALIDITY'])
            if pupil_diameter_valid(row['RightPupilDiameter']):
                right_bitmask |= (1 << validity_map['SINGLE_EYE_DATA_PUPIL_DIAMETER_VALIDITY'])
ved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv

# %% [markdown]
# ### Calculate Gaze Direction (Ex) and Median Rolling Window of 10 (Filtered_Ex)

# %%
filtered_folder = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Filtered_EyeTrackingData"

for folder in [filtered_folder]:
    for file_name in os.listdir(folder):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder, file_name)
            dtype_spec = {
                'LeftGazeX': float,
                'LeftGazeZ': float,
                'RightGazeX': float,
                'RightGazeZ': float,
                'FixationPointX': float,
                'FixationPointZ': float,
            }
            
            df = pd.read_csv(file_path, dtype=dtype_spec)
            
            # Compute LeftEx, RightEx, and CombinedEx
            df['LeftEx'] = np.arctan2(df['LeftGazeX'], df['LeftGazeZ']) / np.pi * 180
            df['RightEx'] = np.arctan2(df['RightGazeX'], df['RightGazeZ']) / np.pi * 180
            df['CombinedEx'] = np.arctan2(df['FixationPointX'], df['FixationPointZ']) / np.pi * 180
            
            # Apply the rolling median filter with a window size of 10
            df['Filtered_LeftEx'] = df['LeftEx'].rolling(window=10).median().fillna(method='bfill')
            df['Filtered_RightEx'] = df['RightEx'].rolling(window=10).median().fillna(method='bfill')
            df['Filtered_CombinedEx'] = df['CombinedEx'].rolling(window=10).median().fillna(method='bfill')
            
            df.to_csv(file_path, index=False)
            print(f"Updated file with Ex values saved to: {file_path}")
# Out:
# Processing file: EyeTrackingData_Participant10_2023_12_07_19_13_57_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant10_2023_12_07_19_13_57_filtered.csv
# Processing file: EyeTrackingData_Participant15_2023_12_11_14_02_52_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant15_2023_12_11_14_02_52_filtered.csv
# Processing file: EyeTrackingData_Participant16_2023_12_11_16_15_30_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant16_2023_12_11_16_15_30_filtered.csv
# Processing file: EyeTrackingData_Participant20_2023_12_11_18_20_19_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant20_2023_12_11_18_20_19_filtered.csv
# Processing file: EyeTrackingData_Participant21_2023_12_12_11_20_59_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant21_2023_12_12_11_20_59_filtered.csv
# Processing file: EyeTrackingData_Participant22_2023_12_12_15_10_01_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant22_2023_12_12_15_10_01_filtered.csv
# Processing file: EyeTrackingData_Participant23_2023_12_12_18_01_13_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant23_2023_12_12_18_01_13_filtered.csv
# Processing file: EyeTrackingData_Participant24_2023_12_13_13_35_48_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant24_2023_12_13_13_35_48_filtered.csv
# Processing file: EyeTrackingData_Participant25_2023_12_13_18_34_56_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant25_2023_12_13_18_34_56_filtered.csv
# Processing file: EyeTrackingData_Participant26_2023_12_14_14_28_00_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant26_2023_12_14_14_28_00_filtered.csv
# Processing file: EyeTrackingData_Participant27_2023_12_14_16_12_49_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant27_2023_12_14_16_12_49_filtered.csv
# Processing file: EyeTrackingData_Participant28_2023_12_14_17_58_57_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant28_2023_12_14_17_58_57_filtered.csv
# Processing file: EyeTrackingData_Participant29_2023_12_15_10_17_24_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant29_2023_12_15_10_17_24_filtered.csv
# Processing file: EyeTrackingData_Participant2_2023_12_07_12_29_23_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant2_2023_12_07_12_29_23_filtered.csv
# Processing file: EyeTrackingData_Participant30_2023_12_15_13_32_17_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant30_2023_12_15_13_32_17_filtered.csv
# Processing file: EyeTrackingData_Participant31_2023_12_15_16_05_36_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant31_2023_12_15_16_05_36_filtered.csv
# Processing file: EyeTrackingData_Participant32_2023_12_18_10_21_54_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant32_2023_12_18_10_21_54_filtered.csv
# Processing file: EyeTrackingData_Participant33_2023_12_18_12_14_51_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Particip
filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant62_2024_01_19_15_39_12_filtered.csv
# Processing file: EyeTrackingData_Participant65_2024_01_22_10_44_35_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant65_2024_01_22_10_44_35_filtered.csv
# Processing file: EyeTrackingData_Participant66_2024_01_22_14_34_48_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant66_2024_01_22_14_34_48_filtered.csv
# Processing file: EyeTrackingData_Participant67_2024_01_22_17_02_36_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant67_2024_01_22_17_02_36_filtered.csv
# Processing file: EyeTrackingData_Participant68_2024_01_23_09_32_01_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant68_2024_01_23_09_32_01_filtered.csv
# Processing file: EyeTrackingData_Participant71_2024_01_23_17_02_55_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant71_2024_01_23_17_02_55_filtered.csv
# Processing file: EyeTrackingData_Participant72_2024_01_26_10_09_07_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant72_2024_01_26_10_09_07_filtered.csv
# Processing file: EyeTrackingData_Participant73_2024_01_29_10_36_24_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant73_2024_01_29_10_36_24_filtered.csv
# Processing file: EyeTrackingData_Participant74_2024_01_30_10_37_48_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant74_2024_01_30_10_37_48_filtered.csv
# Processing file: EyeTrackingData_Participant75_2024_01_30_12_40_11_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant75_2024_01_30_12_40_11_filtered.csv
# Processing file: EyeTrackingData_Participant76_2024_01_30_14_34_40_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant76_2024_01_30_14_34_40_filtered.csv
# Processing file: EyeTrackingData_Participant77_2024_01_30_16_37_18_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant77_2024_01_30_16_37_18_filtered.csv
# Processing file: EyeTrackingData_Participant78_2024_01_30_18_03_07_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant78_2024_01_30_18_03_07_filtered.csv
# Processing file: EyeTrackingData_Participant79_2024_01_31_18_03_52_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant79_2024_01_31_18_03_52_filtered.csv
# Processing file: EyeTrackingData_Participant80_2024_02_02_13_04_47_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant80_2024_02_02_13_04_47_filtered.csv
# Processing file: EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv
# Updated file with Ex values saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv

# %% [markdown]
# ### Calculate Time_Diff and Initial_Velocity (using Ex)

# %%
filtered_folder = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Filtered_EyeTrackingData"

for folder in [filtered_folder]:
    for file_name in os.listdir(folder):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder, file_name)
            dtype_spec = {
                'LeftGazeX': float,
                'LeftGazeZ': float,
                'RightGazeX': float,
                'RightGazeZ': float,
                'FixationPointX': float,
                'FixationPointZ': float,
                'Timestamp': str
            }
            
            df = pd.read_csv(file_path, dtype=dtype_spec)
            
            # Convert 'Timestamp' column to datetime
            df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
            df.dropna(subset=['Timestamp'], inplace=True)
            
            # Calculate time difference in seconds
            df['Time_Diff'] = df['Timestamp'].diff().dt.total_seconds()
            df['Time_Diff'] = df['Time_Diff'].replace(0, 1e-6)  # Prevent division by zero
            df['Time_Diff'].fillna(method='bfill', inplace=True)  # Backward fill
            df['Time_Diff'].fillna(method='ffill', inplace=True)  # Forward fill
            
            # Compute velocity for raw gaze direction data
            df['Initial_Velocity_LeftEx'] = df['LeftEx'].diff() / df['Time_Diff']
            df['Initial_Velocity_RightEx'] = df['RightEx'].diff() / df['Time_Diff']
            df['Initial_Velocity_CombinedEx'] = df['CombinedEx'].diff() / df['Time_Diff']

            df.to_csv(file_path, index=False)
            print(f"Intermediate file with initial velocities saved to: {file_path}")
# Out:
# Processing file: EyeTrackingData_Participant10_2023_12_07_19_13_57_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Particip
filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant73_2024_01_29_10_36_24_filtered.csv
# Processing file: EyeTrackingData_Participant74_2024_01_30_10_37_48_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant74_2024_01_30_10_37_48_filtered.csv
# Processing file: EyeTrackingData_Participant75_2024_01_30_12_40_11_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant75_2024_01_30_12_40_11_filtered.csv
# Processing file: EyeTrackingData_Participant76_2024_01_30_14_34_40_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant76_2024_01_30_14_34_40_filtered.csv
# Processing file: EyeTrackingData_Participant77_2024_01_30_16_37_18_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant77_2024_01_30_16_37_18_filtered.csv
# Processing file: EyeTrackingData_Participant78_2024_01_30_18_03_07_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant78_2024_01_30_18_03_07_filtered.csv
# Processing file: EyeTrackingData_Participant79_2024_01_31_18_03_52_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant79_2024_01_31_18_03_52_filtered.csv
# Processing file: EyeTrackingData_Participant80_2024_02_02_13_04_47_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant80_2024_02_02_13_04_47_filtered.csv
# Processing file: EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv
# Intermediate file with initial velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv

# %% [markdown]
# ### Calculate Filtered_Velocity (using Filtered_Ex) and Normalize [-1 to 1]

# %%
filtered_folder = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Filtered_EyeTrackingData"

for folder in [filtered_folder]:
    for file_name in os.listdir(folder):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder, file_name)
            
            df = pd.read_csv(file_path)
            
            # Identify where filtered data changes
            #df['Filtered_LeftEx_Change'] = df['Filtered_LeftEx'].ne(df['Filtered_LeftEx'].shift())
            #df['Filtered_RightEx_Change'] = df['Filtered_RightEx'].ne(df['Filtered_RightEx'].shift())
            #df['Filtered_CombinedEx_Change'] = df['Filtered_CombinedEx'].ne(df['Filtered_CombinedEx'].shift())

            # Compute velocity for filtered gaze direction data
            df['Filtered_Velocity_LeftEx'] = df['Filtered_LeftEx'].diff() / df['Time_Diff']
            df['Filtered_Velocity_RightEx'] = df['Filtered_RightEx'].diff() / df['Time_Diff']
            df['Filtered_Velocity_CombinedEx'] = df['Filtered_CombinedEx'].diff() / df['Time_Diff']

            #df.loc[~df['Filtered_LeftEx_Change'], 'Filtered_Velocity_LeftEx'] = np.nan
            #df.loc[~df['Filtered_RightEx_Change'], 'Filtered_Velocity_RightEx'] = np.nan
            #df.loc[~df['Filtered_CombinedEx_Change'], 'Filtered_Velocity_CombinedEx'] = np.nan

            # Forward fill only within gaps
            df['Filtered_Velocity_LeftEx'].fillna(method='ffill', inplace=True)
            df['Filtered_Velocity_RightEx'].fillna(method='ffill', inplace=True)
            df['Filtered_Velocity_CombinedEx'].fillna(method='ffill', inplace=True)

            # Normalize velocity to range [-1, 1]
            for col in ['Filtered_Velocity_LeftEx', 'Filtered_Velocity_RightEx', 'Filtered_Velocity_CombinedEx']:
                min_val, max_val = df[col].min(), df[col].max()
                if max_val - min_val > 1e-6:
                    df[f'Normalized_{col}'] = (2 * ((df[col] - min_val) / (max_val - min_val))) - 1
                else:
                    df[f'Normalized_{col}'] = 0  # Avoid division by zero

            #df.drop(columns=['Filtered_LeftEx_Change', 'Filtered_RightEx_Change', 'Filtered_CombinedEx_Change'], inplace=True)

            df.to_csv(file_path, index=False)
            print(f"Updated file with filtered velocities saved to: {file_path}")
# Out:
# Updated file with filtered velocities saved to: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Filtered_EyeTrackingData\EyeTrackingData_Particip
    file_path = os.path.join(filtered_folder, file)
    df = pd.read_csv(file_path)
    
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
    df['Timestamp_ms'] = (df['Timestamp'] - df['Timestamp'].min()).dt.total_seconds() * 1000  # Store original datetime format
    df['CurrentTrial'] = pd.to_numeric(df['CurrentTrial'], errors='coerce')
    df = df[(df['CurrentTrial'] >= 1) & (df['CurrentTrial'] <= 32)]
    
    gaze_x = df['FixationPointX'].values
    gaze_y = df['FixationPointY'].values
    timestamps = df['Timestamp_ms'].values
    velocity = df['Filtered_Velocity_CombinedEx'].values
    trials = df['CurrentTrial'].values
    
    # Fixation Detection (I-DT Method)
    all_fixations = []
    start_idx = 0
    for i in range(1, len(gaze_x)):
        window_x = gaze_x[start_idx:i+1]
        window_y = gaze_y[start_idx:i+1]
        if (np.max(window_x) - np.min(window_x) <= FIXATION_DISPERSION_THRESHOLD and
            np.max(window_y) - np.min(window_y) <= FIXATION_DISPERSION_THRESHOLD):
            continue
        duration = timestamps[i-1] - timestamps[start_idx]
        if duration >= FIXATION_MIN_DURATION:
            fixation_x = np.mean(gaze_x[start_idx:i])
            fixation_y = np.mean(gaze_y[start_idx:i])
            start_time = df['Timestamp'].iloc[start_idx]  
            end_time = df['Timestamp'].iloc[i-1]  
            all_fixations.append([trials[start_idx], start_time, end_time, duration, fixation_x, fixation_y])
        start_idx = i
    
    # Saccade Detection (I-VT Method)
    all_saccades = []
    saccade_indices, _ = find_peaks(velocity, height=SACCADE_VELOCITY_THRESHOLD)
    for idx in saccade_indices:
        if idx > 0 and idx < len(timestamps) - 1:
            start_time = df['Timestamp'].iloc[idx - 1]  
            end_time = df['Timestamp'].iloc[idx + 1]  
            duration = (end_time - start_time).total_seconds() * 1000  # Convert to milliseconds
            all_saccades.append([trials[idx], start_time, end_time, duration, gaze_x[idx - 1], gaze_y[idx - 1], gaze_x[idx + 1], gaze_y[idx + 1]])
    
    fixation_df = pd.DataFrame(all_fixations, columns=['CurrentTrial', 'start_time', 'end_time', 'duration_fixation', 'fixation_X', 'fixation_Y'])
    fixation_file = file.replace("_filtered.csv", "_filtered_fixations.csv")
    fixation_df.to_csv(os.path.join(output_dir, fixation_file), index=False)
    saccade_df = pd.DataFrame(all_saccades, columns=['CurrentTrial', 'start_time', 'end_time', 'duration_saccade', 'start_X', 'start_Y', 'end_X', 'end_Y'])
    saccade_file = file.replace("_filtered.csv", "_filtered_saccades.csv")
    saccade_df.to_csv(os.path.join(output_dir, saccade_file), index=False)
    
    print(f"Processed: {file} -> Saved fixations and saccades")

print("All files processed successfully!")
# Out:
# Processed: EyeTrackingData_Participant10_2023_12_07_19_13_57_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant15_2023_12_11_14_02_52_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant16_2023_12_11_16_15_30_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant20_2023_12_11_18_20_19_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant21_2023_12_12_11_20_59_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant22_2023_12_12_15_10_01_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant23_2023_12_12_18_01_13_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant24_2023_12_13_13_35_48_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant25_2023_12_13_18_34_56_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant26_2023_12_14_14_28_00_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant27_2023_12_14_16_12_49_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant28_2023_12_14_17_58_57_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant29_2023_12_15_10_17_24_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant2_2023_12_07_12_29_23_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant30_2023_12_15_13_32_17_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant31_2023_12_15_16_05_36_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant32_2023_12_18_10_21_54_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant33_2023_12_18_12_14_51_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant34_2023_12_18_14_09_13_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant35_2023_12_18_16_10_31_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant36_2023_12_18_18_29_35_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant37_2023_12_19_10_01_52_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant38_2023_12_19_11_31_47_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant39_2023_12_19_14_17_15_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant3_2023_12_07_14_37_09_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant40_2023_12_19_16_04_39_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant41_2023_12_19_18_08_42_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant44_2024_01_08_14_32_05_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant45_2024_01_09_10_03_25_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant46_2024_01_09_14_03_48_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant47_2024_01_10_17_39_05_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant48_2024_01_11_13_14_50_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant49_2024_01_12_10_08_55_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant4_2023_12_07_16_52_11_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant50_2024_01_12_12_43_28_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant51_2024_01_12_17_46_37_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant52_2024_01_15_10_40_04_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant53_2024_01_15_14_42_54_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant54_2024_01_15_17_06_51_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant56_2024_01_16_09_57_16_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant57_2024_01_16_11_30_34_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant59_2024_01_16_13_12_08_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant60_2024_01_18_16_07_15_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant61_2024_01_19_10_05_34_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant62_2024_01_19_15_39_12_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant65_2024_01_22_10_44_35_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant66_2024_01_22_14_34_48_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant67_2024_01_22_17_02_36_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant68_2024_01_23_09_32_01_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant71_2024_01_23_17_02_55_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant72_2024_01_26_10_09_07_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant73_2024_01_29_10_36_24_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant74_2024_01_30_10_37_48_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant75_2024_01_30_12_40_11_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant76_2024_01_30_14_34_40_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant77_2024_01_30_16_37_18_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant78_2024_01_30_18_03_07_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant79_2024_01_31_18_03_52_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant80_2024_02_02_13_04_47_filtered.csv -> Saved fixations and saccades
# Processed: EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv -> Saved fixations and saccades
# All files processed successfully!

# %% [markdown]
# ### Extract Fixation and Saccade Features into Dataframe for .csv (eye_tracking_analysis_trials.csv)

# %%
data_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"

def load_data(file_path):
    return pd.read_csv(file_path)

def calculate_statistics_with_counts(df, group_by_column='CurrentTrial'):
    avg_stats = df.groupby(group_by_column).mean().reset_index()
    counts = df.groupby(group_by_column).size().reset_index(name='count')
    return pd.merge(avg_stats, counts, on=group_by_column)

results = []

pattern = re.compile(r'EyeTrackingData_Participant(\d+)_.*_filtered_(fixations|saccades)')

for file_name in os.listdir(data_dir):
    match = pattern.match(file_name)
    if match:
        participant_id = int(match.group(1))
        data_type = match.group(2)
        
        if data_type == 'fixations':
            fixations_file = os.path.join(data_dir, file_name)
            saccades_file = os.path.join(data_dir, file_name.replace('fixations', 'saccades'))
            
            if os.path.exists(saccades_file):
                fixations_df = load_data(fixations_file)
                saccades_df = load_data(saccades_file)
                
                fixations_stats = calculate_statistics_with_counts(fixations_df)
                saccades_stats = calculate_statistics_with_counts(saccades_df)
                
                avg_stats = pd.merge(fixations_stats, saccades_stats, on='CurrentTrial', suffixes=('_fixations', '_saccades'))
                avg_stats['ParticipantID'] = participant_id
                
                results.append(avg_stats)

eye_tracking_analysis_df = pd.concat(results, ignore_index=True)
eye_tracking_analysis_df = eye_tracking_analysis_df.sort_values(by=['ParticipantID', 'CurrentTrial'])

# CurrentTrial is in the range [1, 32]
eye_tracking_analysis_df = eye_tracking_analysis_df[(eye_tracking_analysis_df['CurrentTrial'] >= 1) & (eye_tracking_analysis_df['CurrentTrial'] <= 32)]
cols = ['ParticipantID'] + [col for col in eye_tracking_analysis_df.columns if col != 'ParticipantID']
eye_tracking_analysis_df = eye_tracking_analysis_df[cols]
eye_tracking_analysis_csv_path = os.path.join(data_dir, 'eye_tracking_analysis_trials.csv')
eye_tracking_analysis_df.to_csv(eye_tracking_analysis_csv_path, index=False)

print(f'Eye-tracking analysis CSV file created at: {eye_tracking_analysis_csv_path}')
# Out:
# Eye-tracking analysis CSV file created at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\eye_tracking_analysis_trials.csv

# %% [markdown]
# ### Convert from Trial-based to Subexperiment-based (eye_tracking_analysis.csv)

# %%
data_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"
output_dir = "C:\\Users\\Mobile Workstation 3\\Documents\\GitHub\\VR_data_analysis"
file_path = os.path.join(data_dir, 'eye_tracking_analysis_trials.csv')

eye_tracking_df = pd.read_csv(file_path)
eye_tracking_df = eye_tracking_df[(eye_tracking_df['CurrentTrial'] != 0) & (eye_tracking_df['CurrentTrial'] != 33)]

# Calculate subexperiment number
eye_tracking_df['subexperiment_number'] = ((eye_tracking_df['CurrentTrial'] - 1) // 4) + 1
eye_tracking_df = eye_tracking_df[['ParticipantID', 'subexperiment_number', 'duration_fixation', 'duration_saccade', 'count_fixations', 'count_saccades']]

# Aggregate data
aggregated_df = eye_tracking_df.groupby(['ParticipantID', 'subexperiment_number']).agg({
    'duration_fixation': 'mean',
    'duration_saccade': 'mean',
    'count_fixations': 'sum',
    'count_saccades': 'sum'
}).reset_index()
aggregated_df.rename(columns={'ParticipantID': 'participant_number'}, inplace=True)

output_file_path = os.path.join(output_dir, 'eye_tracking_analysis.csv')
aggregated_df.to_csv(output_file_path, index=False)

print("eye_tracking_analysis.csv has been created successfully.")
# Out:
# eye_tracking_analysis.csv has been created successfully.

# %% [markdown]
# ### Calculate Fixation and Saccades - Tutorial

# %%
filtered_folder = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Filtered_EyeTrackingData"
output_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"
csv_files = [f for f in os.listdir(filtered_folder) if f.endswith("_filtered.csv")]

FIXATION_DISPERSION_THRESHOLD = 0.1  # Max distance in degrees/pixels
FIXATION_MIN_DURATION = 100         # Min duration in ms
SACCADE_VELOCITY_THRESHOLD = 30     # Degrees per second

for file in csv_files:
    file_path = os.path.join(filtered_folder, file)
    df = pd.read_csv(file_path)
    
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
    df['Timestamp_ms'] = (df['Timestamp'] - df['Timestamp'].min()).dt.total_seconds() * 1000
    df['CurrentTutorial'] = pd.to_numeric(df['CurrentTutorial'], errors='coerce')
    
    df = df[df['CurrentTutorial'].isin([18, 21, 24])]
    
    gaze_x = df['FixationPointX'].values
    gaze_y = df['FixationPointY'].values
    timestamps = df['Timestamp_ms'].values
    velocity = df['Filtered_Velocity_CombinedEx'].values
    tutorials = df['CurrentTutorial'].values
    
    # Fixation Detection (I-DT Method)
    all_fixations = []
    start_idx = 0
    for i in range(1, len(gaze_x)):
        window_x = gaze_x[start_idx:i+1]
        window_y = gaze_y[start_idx:i+1]
        if (np.max(window_x) - np.min(window_x) <= FIXATION_DISPERSION_THRESHOLD and
            np.max(window_y) - np.min(window_y) <= FIXATION_DISPERSION_THRESHOLD):
            continue
        duration = timestamps[i-1] - timestamps[start_idx]
        if duration >= FIXATION_MIN_DURATION:
            fixation_x = np.mean(gaze_x[start_idx:i])
            fixation_y = np.mean(gaze_y[start_idx:i])
            start_time = df['Timestamp'].iloc[start_idx]
            end_time = df['Timestamp'].iloc[i-1]
            all_fixations.append([tutorials[start_idx], start_time, end_time, duration, fixation_x, fixation_y])
        start_idx = i
        
    # Saccade Detection (I-VT Method)
    all_saccades = []
    saccade_indices, _ = find_peaks(velocity, height=SACCADE_VELOCITY_THRESHOLD)
    for idx in saccade_indices:
        if idx > 0 and idx < len(timestamps) - 1:
            start_time = df['Timestamp'].iloc[idx - 1]
            end_time = df['Timestamp'].iloc[idx + 1]
            duration = (end_time - start_time).total_seconds() * 1000  # Convert to milliseconds
            all_saccades.append([tutorials[idx], start_time, end_time, duration,
                                  gaze_x[idx - 1], gaze_y[idx - 1], gaze_x[idx + 1], gaze_y[idx + 1]])
    
    fixation_df = pd.DataFrame(all_fixations, columns=['CurrentTutorial', 'start_time', 'end_time', 'duration_fixation', 'fixation_X', 'fixation_Y'])
    fixation_file = file.replace("_filtered.csv", "_filtered_fixations_tutorial.csv")
    fixation_df.to_csv(os.path.join(output_dir, fixation_file), index=False)
    saccade_df = pd.DataFrame(all_saccades, columns=['CurrentTutorial', 'start_time', 'end_time', 'duration_saccade', 'start_X', 'start_Y', 'end_X', 'end_Y'])
    saccade_file = file.replace("_filtered.csv", "_filtered_saccades_tutorial.csv")
    saccade_df.to_csv(os.path.join(output_dir, saccade_file), index=False)
    
    print(f"Processed: {file} -> Saved fixations and saccades for tutorial data")

print("All files processed successfully using tutorial data!")
# Out:
# Processed: EyeTrackingData_Participant10_2023_12_07_19_13_57_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant15_2023_12_11_14_02_52_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant16_2023_12_11_16_15_30_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant20_2023_12_11_18_20_19_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant21_2023_12_12_11_20_59_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant22_2023_12_12_15_10_01_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant23_2023_12_12_18_01_13_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant24_2023_12_13_13_35_48_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant25_2023_12_13_18_34_56_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant26_2023_12_14_14_28_00_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant27_2023_12_14_16_12_49_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant28_2023_12_14_17_58_57_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant29_2023_12_15_10_17_24_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant2_2023_12_07_12_29_23_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant30_2023_12_15_13_32_17_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant31_2023_12_15_16_05_36_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant32_2023_12_18_10_21_54_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant33_2023_12_18_12_14_51_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant34_2023_12_18_14_09_13_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant35_2023_12_18_16_10_31_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant36_2023_12_18_18_29_35_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant37_2023_12_19_10_01_52_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant38_2023_12_19_11_31_47_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant39_2023_12_19_14_17_15_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant3_2023_12_07_14_37_09_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant40_2023_12_19_16_04_39_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant41_2023_12_19_18_08_42_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant44_2024_01_08_14_32_05_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant45_2024_01_09_10_03_25_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant46_2024_01_09_14_03_48_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant47_2024_01_10_17_39_05_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant48_2024_01_11_13_14_50_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant49_2024_01_12_10_08_55_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant4_2023_12_07_16_52_11_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant50_2024_01_12_12_43_28_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant51_2024_01_12_17_46_37_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant52_2024_01_15_10_40_04_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant53_2024_01_15_14_42_54_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant54_2024_01_15_17_06_51_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant56_2024_01_16_09_57_16_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant57_2024_01_16_11_30_34_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant59_2024_01_16_13_12_08_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant60_2024_01_18_16_07_15_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant61_2024_01_19_10_05_34_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant62_2024_01_19_15_39_12_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant65_2024_01_22_10_44_35_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant66_2024_01_22_14_34_48_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant67_2024_01_22_17_02_36_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant68_2024_01_23_09_32_01_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant71_2024_01_23_17_02_55_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant72_2024_01_26_10_09_07_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant73_2024_01_29_10_36_24_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant74_2024_01_30_10_37_48_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant75_2024_01_30_12_40_11_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant76_2024_01_30_14_34_40_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant77_2024_01_30_16_37_18_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant78_2024_01_30_18_03_07_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant79_2024_01_31_18_03_52_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant80_2024_02_02_13_04_47_filtered.csv -> Saved fixations and saccades for tutorial data
# Processed: EyeTrackingData_Participant81_2024_02_02_14_11_58_filtered.csv -> Saved fixations and saccades for tutorial data
# All files processed successfully using tutorial data!

# %% [markdown]
# ### Extract Fixation and Saccade Features into Dataframe for .csv - Tutorial

# %%
import os
import re
import pandas as pd

data_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"
output_dir = "C:\\Users\\Mobile Workstation 3\\Documents\\GitHub\\VR_data_analysis"

def load_data(file_path):
    return pd.read_csv(file_path)

def calculate_statistics_with_counts(df, group_by_column='CurrentTutorial'):
    avg_stats = df.groupby(group_by_column).mean().reset_index()
    counts = df.groupby(group_by_column).size().reset_index(name='count')
    return pd.merge(avg_stats, counts, on=group_by_column)

results = []

pattern = re.compile(r'EyeTrackingData_Participant(\d+)_.*_filtered_(fixations_tutorial|saccades_tutorial)')

for file_name in os.listdir(data_dir):
    match = pattern.match(file_name)
    if match:
        participant_id = int(match.group(1))
        data_type = match.group(2)
        
        if data_type == 'fixations_tutorial':
            fixations_file = os.path.join(data_dir, file_name)
            saccades_file = os.path.join(data_dir, file_name.replace('fixations_tutorial', 'saccades_tutorial'))
            
            if os.path.exists(saccades_file):
                fixations_df = load_data(fixations_file)
                saccades_df = load_data(saccades_file)
                
                fixations_df = fixations_df[fixations_df['CurrentTutorial'].isin([18, 21, 24])]
                saccades_df = saccades_df[saccades_df['CurrentTutorial'].isin([18, 21, 24])]
                
                fixations_stats = calculate_statistics_with_counts(fixations_df, group_by_column='CurrentTutorial')
                saccades_stats = calculate_statistics_with_counts(saccades_df, group_by_column='CurrentTutorial')
                
                avg_stats = pd.merge(fixations_stats, saccades_stats, on='CurrentTutorial', suffixes=('_fixations', '_saccades'))
                avg_stats['ParticipantID'] = participant_id
                
                results.append(avg_stats)

eye_tracking_analysis_df = pd.concat(results, ignore_index=True)
eye_tracking_analysis_df = eye_tracking_analysis_df.sort_values(by=['ParticipantID', 'CurrentTutorial'])
eye_tracking_analysis_df = eye_tracking_analysis_df[eye_tracking_analysis_df['CurrentTutorial'].isin([18, 21, 24])]

mapping = {18: 0, 21: 1, 24: 2}
eye_tracking_analysis_df['CurrentTutorial'] = eye_tracking_analysis_df['CurrentTutorial'].map(mapping)
cols = ['ParticipantID'] + [col for col in eye_tracking_analysis_df.columns if col != 'ParticipantID']
eye_tracking_analysis_df = eye_tracking_analysis_df[cols]

selected_columns = ['ParticipantID', 'CurrentTutorial', 'duration_fixation', 'duration_saccade', 'count_fixations', 'count_saccades']
tutorial_df = eye_tracking_analysis_df[selected_columns].copy()
tutorial_df = tutorial_df.rename(columns={
    'ParticipantID': 'participant_number',
    'CurrentTutorial': 'tutorial_number',
    'duration_fixation': 'duration_fixation',
    'duration_saccade': 'duration_saccade'
})

output_trials_file = os.path.join(data_dir, 'eye_tracking_analysis_trials_tutorial.csv')
eye_tracking_analysis_df.to_csv(output_trials_file, index=False)
tutorial_output_file = os.path.join(output_dir, 'eye_tracking_analysis_tutorial.csv')
tutorial_df.to_csv(tutorial_output_file, index=False)

print(f'Eye-tracking analysis CSV file created at: {output_trials_file}')
print(f'Eye-tracking tutorial CSV file saved at: {tutorial_output_file}')
# Out:
# Eye-tracking analysis CSV file created at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\eye_tracking_analysis_trials_tutorial.csv
# Eye-tracking tutorial CSV file saved at: C:\Users\Mobile Workstation 3\Documents\GitHub\VR_data_analysis\eye_tracking_analysis_tutorial.csv

# %% [markdown]
# ### Calculate Blink Features

# %%
data_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Raw_EyeTrackingData"
output_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"

def load_data(file_path):
    return pd.read_csv(file_path)

def perform_blink_analysis(df):
    
    blink_info_per_trial = {}

    trials = df['CurrentTrial'].unique()

    for trial in trials:
        trial_df = df[df['CurrentTrial'] == trial]

        # Initialize a counter, two flags, and two timestamps
        blink_count = 0
        previous_row_was_zero = False
        two_previous_rows_were_zero = False
        three_previous_rows_were_zero = False
        blink_start_time = None
        blink_end_time = None

        blink_info = {}

        for _, row in trial_df.iterrows():
            # Check if the current row has 0 for LeftGazeX, LeftGazeY, LeftGazeZ
            current_row_is_zero = (row['LeftGazeX'] == 0) and (row['LeftGazeY'] == 0) and (row['LeftGazeZ'] == 0)

            # If the last three rows were zero and the current row is not zero, increment the counter and calculate the blink duration
            if three_previous_rows_were_zero and not current_row_is_zero:
                blink_end_time = pd.to_datetime(row['Timestamp'], infer_datetime_format=True, errors='coerce') 
                blink_duration = (blink_end_time - blink_start_time).total_seconds()
                blink_info[f'blink_{blink_count}'] = {'start_time': blink_start_time, 'end_time': blink_end_time, 'duration': blink_duration}
                blink_count += 1

            # If the current row is zero and the last three rows were not zero, record the start time of the blink
            elif current_row_is_zero and not previous_row_was_zero:
                blink_start_time = pd.to_datetime(row['Timestamp'], infer_datetime_format=True, errors='coerce')  

            # Update the flags
            three_previous_rows_were_zero = two_previous_rows_were_zero and previous_row_was_zero and current_row_is_zero
            two_previous_rows_were_zero = previous_row_was_zero and current_row_is_zero
            previous_row_was_zero = current_row_is_zero

        blink_info_per_trial[trial] = {'blink_info': blink_info, 'blink_count': blink_count}

    return blink_info_per_trial

pattern = re.compile(r'EyeTrackingData_Participant(\d+)_.*')

for file_name in os.listdir(data_dir):
    match = pattern.match(file_name)
    if match and file_name.endswith('.csv'):
        participant_id = match.group(1)
        file_path = os.path.join(data_dir, file_name)
        
        df = load_data(file_path)
        blink_info_per_trial = perform_blink_analysis(df)
        
        blink_info_list = []
        for trial, info in blink_info_per_trial.items():
            for blink_id, blink_data in info['blink_info'].items():
                blink_info_list.append({
                    'ParticipantID': participant_id,
                    'CurrentTrial': trial,
                    'BlinkID': blink_id,
                    'StartTime': blink_data['start_time'],
                    'EndTime': blink_data['end_time'],
                    'Duration': blink_data['duration']
                })
        
        blink_df = pd.DataFrame(blink_info_list)
        
        blink_file_name = file_name.replace(".csv", "_blinks.csv")
        output_file_path = os.path.join(output_dir, blink_file_name)
        blink_df.to_csv(output_file_path, index=False)

        print(f'Blink analysis CSV file created for Participant {participant_id} at: {output_file_path}')
# Out:
# C:\Users\Mobile Workstation 3\AppData\Local\Temp\ipykernel_26732\3055675896.py:58: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = load_data(file_path)
# Blink analysis CSV file created for Participant 10 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant10_2023_12_07_19_13_57_blinks.csv
# Blink analysis CSV file created for Participant 15 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant15_2023_12_11_14_02_52_blinks.csv
# Blink analysis CSV file created for Participant 16 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant16_2023_12_11_16_15_30_blinks.csv
# Blink analysis CSV file created for Participant 20 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant20_2023_12_11_18_20_19_blinks.csv
# Blink analysis CSV file created for Participant 21 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant21_2023_12_12_11_20_59_blinks.csv
# Blink analysis CSV file created for Participant 22 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant22_2023_12_12_15_10_01_blinks.csv
# Blink analysis CSV file created for Participant 23 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant23_2023_12_12_18_01_13_blinks.csv
# Blink analysis CSV file created for Participant 24 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant24_2023_12_13_13_35_48_blinks.csv
# Blink analysis CSV file created for Participant 25 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant25_2023_12_13_18_34_56_blinks.csv
# Blink analysis CSV file created for Participant 26 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant26_2023_12_14_14_28_00_blinks.csv
# Blink analysis CSV file created for Participant 27 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant27_2023_12_14_16_12_49_blinks.csv
# Blink analysis CSV file created for Participant 28 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant28_2023_12_14_17_58_57_blinks.csv
# Blink analysis CSV file created for Participant 29 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant29_2023_12_15_10_17_24_blinks.csv
# Blink analysis CSV file created for Participant 2 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant2_2023_12_07_12_29_23_blinks.csv
# Blink analysis CSV file created for Participant 30 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant30_2023_12_15_13_32_17_blinks.csv
# Blink analysis CSV file created for Participant 31 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant31_2023_12_15_16_05_36_blinks.csv
# Blink analysis CSV file created for Participant 32 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant32_2023_12_18_10_21_54_blinks.csv
# Blink analysis CSV file created for Participant 33 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant33_2023_12_18_12_14_51_blinks.csv
# Blink analysis CSV file created for Participant 34 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant34_2023_12_18_14_09_13_blinks.csv
# Blink analysis CSV file created for Participant 35 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant35_2023_12_18_16_10_31_blinks.csv
# Blink analysis CSV file created for Participant 36 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant36_2023_12_18_18_29_35_blinks.csv
# Blink analysis CSV file created for Participant 37 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant37_2023_12_19_10_01_52_blinks.csv
# Blink analysis CSV file created for Participant 38 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant38_2023_12_19_11_31_47_blinks.csv
# Blink analysis CSV file created for Participant 39 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant39_2023_12_19_14_17_15_blinks.csv
# Blink analysis CSV file created for Participant 3 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant3_2023_12_07_14_37_09_blinks.csv
# Blink analysis CSV file created for Participant 40 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant40_2023_12_19_16_04_39_blinks.csv
# Blink analysis CSV file created for Participant 41 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant41_2023_12_19_18_08_42_blinks.csv
# Blink analysis CSV file created for Participant 44 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant44_2024_01_08_14_32_05_blinks.csv
# Blink analysis CSV file created for Participant 45 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant45_2024_01_09_10_03_25_blinks.csv
# Blink analysis CSV file created for Participant 46 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant46_2024_01_09_14_03_48_blinks.csv
# Blink analysis CSV file created for Participant 47 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant47_2024_01_10_17_39_05_blinks.csv
# Blink analysis CSV file created for Participant 48 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant48_2024_01_11_13_14_50_blinks.csv
# Blink analysis CSV file created for Participant 49 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant49_2024_01_12_10_08_55_blinks.csv
# Blink analysis CSV file created for Participant 4 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant4_2023_12_07_16_52_11_blinks.csv
# Blink analysis CSV file created for Participant 50 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant50_2024_01_12_12_43_28_blinks.csv
# Blink analysis CSV file created for Participant 51 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant51_2024_01_12_17_46_37_blinks.csv
# Blink analysis CSV file created for Participant 52 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant52_2024_01_15_10_40_04_blinks.csv
# Blink analysis CSV file created for Participant 53 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant53_2024_01_15_14_42_54_blinks.csv
# Blink analysis CSV file created for Participant 54 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant54_2024_01_15_17_06_51_blinks.csv
# Blink analysis CSV file created for Participant 56 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant56_2024_01_16_09_57_16_blinks.csv
# Blink analysis CSV file created for Participant 57 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant57_2024_01_16_11_30_34_blinks.csv
# Blink analysis CSV file created for Participant 59 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant59_2024_01_16_13_12_08_blinks.csv
# Blink analysis CSV file created for Participant 60 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant60_2024_01_18_16_07_15_blinks.csv
# Blink analysis CSV file created for Participant 61 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant61_2024_01_19_10_05_34_blinks.csv
# Blink analysis CSV file created for Participant 62 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant62_2024_01_19_15_39_12_blinks.csv
# Blink analysis CSV file created for Participant 65 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant65_2024_01_22_10_44_35_blinks.csv
# Blink analysis CSV file created for Participant 66 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant66_2024_01_22_14_34_48_blinks.csv
# Blink analysis CSV file created for Participant 67 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant67_2024_01_22_17_02_36_blinks.csv
# Blink analysis CSV file created for Participant 68 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant68_2024_01_23_09_32_01_blinks.csv
# Blink analysis CSV file created for Participant 71 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant71_2024_01_23_17_02_55_blinks.csv
# Blink analysis CSV file created for Participant 72 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant72_2024_01_26_10_09_07_blinks.csv
# Blink analysis CSV file created for Participant 73 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant73_2024_01_29_10_36_24_blinks.csv
# Blink analysis CSV file created for Participant 74 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant74_2024_01_30_10_37_48_blinks.csv
# Blink analysis CSV file created for Participant 75 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant75_2024_01_30_12_40_11_blinks.csv
# Blink analysis CSV file created for Participant 76 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant76_2024_01_30_14_34_40_blinks.csv
# Blink analysis CSV file created for Participant 77 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant77_2024_01_30_16_37_18_blinks.csv
# Blink analysis CSV file created for Participant 78 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant78_2024_01_30_18_03_07_blinks.csv
# Blink analysis CSV file created for Participant 79 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant79_2024_01_31_18_03_52_blinks.csv
# Blink analysis CSV file created for Participant 80 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant80_2024_02_02_13_04_47_blinks.csv
# Blink analysis CSV file created for Participant 81 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant81_2024_02_02_14_11_58_blinks.csv

# %% [markdown]
# ### Extract Blink Features into Dataframe for .csv

# %%
import os
import pandas as pd
import re

blink_data_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"
output_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"

def load_data(file_path):
    return pd.read_csv(file_path)

blink_analysis_results = []

blink_pattern = re.compile(r'EyeTrackingData_Participant(\d+)_.*_blinks')

for file_name in os.listdir(blink_data_dir):
    match = blink_pattern.match(file_name)
    if match:
        print(f"Processing file: {file_name}")  # Debug print
        participant_id = int(match.group(1)) 
        blink_file = os.path.join(blink_data_dir, file_name)
        blink_df = load_data(blink_file)
        blink_df = blink_df[blink_df['CurrentTrial'].apply(lambda x: str(x).isdigit())]
        blink_df['ParticipantID'] = blink_df['ParticipantID'].astype(int)
        blink_df['CurrentTrial'] = blink_df['CurrentTrial'].astype(int)
        blink_stats = blink_df.groupby('CurrentTrial').agg(
            number_of_blinks=('BlinkID', 'count'),
            avg_blink_duration=('Duration', 'mean')
        ).reset_index()
        blink_stats['ParticipantID'] = participant_id
        
        for _, row in blink_stats.iterrows():
            blink_analysis_results.append({
                'ParticipantID': row['ParticipantID'],
                'Trial': row['CurrentTrial'],
                'number_of_blinks': row['Number_of_Blinks'],
                'avg_blink_duration': row['avg_blink_Duration']
            })

# Debug print to check the content of blink_analysis_results
print(f"Total records in blink_analysis_results: {len(blink_analysis_results)}")
for record in blink_analysis_results:
    print(record)

blink_analysis_df = pd.DataFrame(blink_analysis_results)

blink_analysis_csv_path = os.path.join(output_dir, 'blink_analysis.csv')
blink_analysis_df.to_csv(blink_analysis_csv_path, index=False)

print(f'Blink analysis CSV file created at: {blink_analysis_csv_path}')
# Out:
# Processing file: EyeTrackingData_Participant10_2023_12_07_19_13_57_blinks.csv
# Processing file: EyeTrackingData_Participant15_2023_12_11_14_02_52_blinks.csv
# Processing file: EyeTrackingData_Participant57_2024_01_16_11_30_34_blinks.csv
# Processing file: EyeTrackingData_Participant59_2024_01_16_13_12_08_blinks.csv
# Processing file: EyeTrackingData_Participant60_2024_01_18_16_07_15_blinks.csv
# Processing file: EyeTrackingData_Participant61_2024_01_19_10_05_34_blinks.csv
# Processing file: EyeTrackingData_Participant62_2024_01_19_15_39_12_blinks.csv
# Processing file: EyeTrackingData_Participant65_2024_01_22_10_44_35_blinks.csv
# Processing file: EyeTrackingData_Participant66_2024_01_22_14_34_48_blinks.csv
# Processing file: EyeTrackingData_Participant67_2024_01_22_17_02_36_blinks.csv
# Processing file: EyeTrackingData_Participant68_2024_01_23_09_32_01_blinks.csv
# Processing file: EyeTrackingData_Participant71_2024_01_23_17_02_55_blinks.csv
# Processing file: EyeTrackingData_Participant72_2024_01_26_10_09_07_blinks.csv
# Processing file: EyeTrackingData_Participant73_2024_01_29_10_36_24_blinks.csv
# Processing file: EyeTrackingData_Participant74_2024_01_30_10_37_48_blinks.csv
# Processing file: EyeTrackingData_Participant75_2024_01_30_12_40_11_blinks.csv
# Processing file: EyeTrackingData_Participant76_2024_01_30_14_34_40_blinks.csv
# Processing file: EyeTrackingData_Participant77_2024_01_30_16_37_18_blinks.csv
# Processing file: EyeTrackingData_Participant78_2024_01_30_18_03_07_blinks.csv
# Processing file: EyeTrackingData_Participant79_2024_01_31_18_03_52_blinks.csv
# Processing file: EyeTrackingData_Participant80_2024_02_02_13_04_47_blinks.csv
# Processing file: EyeTrackingData_Participant81_2024_02_02_14_11_58_blinks.csv
# Total records in blink_analysis_results: 33
# {'ParticipantID': 3.0, 'Trial': 0.0, 'number_of_blinks': 4.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 1.0, 'number_of_blinks': 2.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 2.0, 'number_of_blinks': 5.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 3.0, 'number_of_blinks': 11.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 4.0, 'number_of_blinks': 5.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 5.0, 'number_of_blinks': 4.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 6.0, 'number_of_blinks': 2.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 7.0, 'number_of_blinks': 1.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 8.0, 'number_of_blinks': 1.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 9.0, 'number_of_blinks': 2.0, 'avg_blink_duration': nan}
# {'ParticipantID': 3.0, 'Trial': 10.0, 'number_of_blinks': 7.0, 'avg_blink_duration': 10.5}
# {'ParticipantID': 3.0, 'Trial': 11.0, 'number_of_blinks': 6.0, 'avg_blink_duration': 8.0}
# {'ParticipantID': 3.0, 'Trial': 12.0, 'number_of_blinks': 6.0, 'avg_blink_duration': 4.0}
# {'ParticipantID': 3.0, 'Trial': 13.0, 'number_of_blinks': 7.0, 'avg_blink_duration': 8.571428571428571}
# {'ParticipantID': 3.0, 'Trial': 14.0, 'number_of_blinks': 2.0, 'avg_blink_duration': 6.0}
# {'ParticipantID': 3.0, 'Trial': 15.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 3.6}
# {'ParticipantID': 3.0, 'Trial': 16.0, 'number_of_blinks': 2.0, 'avg_blink_duration': 6.0}
# {'ParticipantID': 3.0, 'Trial': 17.0, 'number_of_blinks': 7.0, 'avg_blink_duration': 3.4285714285714284}
# {'ParticipantID': 3.0, 'Trial': 18.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 6.0}
# {'ParticipantID': 3.0, 'Trial': 19.0, 'number_of_blinks': 3.0, 'avg_blink_duration': 8.0}
# {'ParticipantID': 3.0, 'Trial': 20.0, 'number_of_blinks': 6.0, 'avg_blink_duration': 8.0}
# {'ParticipantID': 3.0, 'Trial': 21.0, 'number_of_blinks': 2.0, 'avg_blink_duration': 9.0}
# {'ParticipantID': 3.0, 'Trial': 22.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 7.2}
# {'ParticipantID': 3.0, 'Trial': 23.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 6.0}
# {'ParticipantID': 3.0, 'Trial': 24.0, 'number_of_blinks': 11.0, 'avg_blink_duration': 4.363636363636363}
# {'ParticipantID': 3.0, 'Trial': 25.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 4.8}
# {'ParticipantID': 3.0, 'Trial': 26.0, 'number_of_blinks': 6.0, 'avg_blink_duration': 5.0}
# {'ParticipantID': 3.0, 'Trial': 27.0, 'number_of_blinks': 7.0, 'avg_blink_duration': 5.142857142857143}
# {'ParticipantID': 3.0, 'Trial': 28.0, 'number_of_blinks': 6.0, 'avg_blink_duration': 3.0}
# {'ParticipantID': 3.0, 'Trial': 29.0, 'number_of_blinks': 6.0, 'avg_blink_duration': 7.0}
# {'ParticipantID': 3.0, 'Trial': 30.0, 'number_of_blinks': 2.0, 'avg_blink_duration': 3.0}
# {'ParticipantID': 3.0, 'Trial': 31.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 3.6}
# {'ParticipantID': 3.0, 'Trial': 32.0, 'number_of_blinks': 5.0, 'avg_blink_duration': 2.4}
# Blink analysis CSV file created at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\blink_analysis.csv

# %%
import os
import pandas as pd
import numpy as np
import re

data_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Raw_EyeTrackingData"
output_dir = "C:\\Users\\Mobile Workstation 3\\OneDrive - Queen's University\\Coding Scripts\\EyeTrackingData\\Eye_Tracking_Features"

def load_data(file_path):
    return pd.read_csv(file_path)

def perform_blink_analysis(df):
    blink_info_per_trial = {}

    df['CurrentTrial'] = pd.to_numeric(df['CurrentTrial'], errors='coerce')

    trials = df['CurrentTrial'].unique()

    for trial in trials:
        if pd.isna(trial) or trial < 1 or trial > 32:
            continue

        trial_df = df[df['CurrentTrial'] == trial]

        blink_count = 0
        previous_row_was_zero = False
        two_previous_rows_were_zero = False
        three_previous_rows_were_zero = False
        blink_start_time = None
        blink_end_time = None

        blink_info = {}

        for _, row in trial_df.iterrows():
            # Check if the current row has 0 for LeftGazeX, LeftGazeY, LeftGazeZ
            current_row_is_zero = (row['LeftGazeX'] == 0) and (row['LeftGazeY'] == 0) and (row['LeftGazeZ'] == 0)

            # If the last three rows were zero and the current row is not zero, increment the counter and calculate the blink duration
            if three_previous_rows_were_zero and not current_row_is_zero:
                blink_end_time = pd.to_datetime(row['Timestamp'], infer_datetime_format=True, errors='coerce') 
                blink_duration = (blink_end_time - blink_start_time).total_seconds()
                blink_info[f'blink_{blink_count}'] = {'Start_Time': blink_start_time, 'End_Time': blink_end_time, 'Duration_blinks': blink_duration}
                blink_count += 1

            # If the current row is zero and the last three rows were not zero, record the start time of the blink
            elif current_row_is_zero and not previous_row_was_zero:
                blink_start_time = pd.to_datetime(row['Timestamp'], infer_datetime_format=True, errors='coerce')  

            # Update the flags
            three_previous_rows_were_zero = two_previous_rows_were_zero and previous_row_was_zero and current_row_is_zero
            two_previous_rows_were_zero = previous_row_was_zero and current_row_is_zero
            previous_row_was_zero = current_row_is_zero

        blink_info_per_trial[trial] = {'blink_info': blink_info, 'blink_count': blink_count}

    return blink_info_per_trial

pattern = re.compile(r'EyeTrackingData_Participant(\d+)_.*')

blink_analysis_results = []

for file_name in os.listdir(data_dir):
    match = pattern.match(file_name)
    if match and file_name.endswith('.csv'):
        participant_id = int(match.group(1))
        file_path = os.path.join(data_dir, file_name)
        
        df = load_data(file_path)
        blink_info_per_trial = perform_blink_analysis(df)
        
        blink_info_list = []
        for trial, info in blink_info_per_trial.items():
            blink_durations = [blink_data['Duration_blinks'] for blink_data in info['blink_info'].values()]
            avg_blink_duration = np.mean(blink_durations) if blink_durations else 0
            
            for blink_id, blink_data in info['blink_info'].items():
                blink_info_list.append({
                    'ParticipantID': participant_id,
                    'CurrentTrial': trial,
                    'BlinkID': blink_id,
                    'Start_Time': blink_data['Start_Time'],
                    'End_Time': blink_data['End_Time'],
                    'Duration_blinks': blink_data['Duration_blinks'],
                    'Avg_Blink_Duration': avg_blink_duration
                })
        
        blink_analysis_results.extend(blink_info_list)
        
        blink_df = pd.DataFrame(blink_info_list)
        
        blink_file_name = file_name.replace(".csv", "_blinks.csv")
        output_file_path = os.path.join(output_dir, blink_file_name)
        blink_df.to_csv(output_file_path, index=False)

        print(f'Blink analysis CSV file created for Participant {participant_id} at: {output_file_path}')

blink_analysis_df = pd.DataFrame(blink_analysis_results)

blink_analysis_summary = blink_analysis_df.groupby(['ParticipantID', 'CurrentTrial']).agg(
    Number_of_Blinks=('BlinkID', 'count'),
    Avg_Blink_Duration=('Avg_Blink_Duration', 'first')
).reset_index()

# Filter out trials outside the range [1, 32]
blink_analysis_summary = blink_analysis_summary[(blink_analysis_summary['CurrentTrial'] >= 1) & (blink_analysis_summary['CurrentTrial'] <= 32)]
blink_analysis_summary = blink_analysis_summary.sort_values(by=['ParticipantID', 'CurrentTrial'])
blink_analysis_summary['CurrentTrial'] = blink_analysis_summary.groupby('ParticipantID').cumcount() + 1
cols = ['ParticipantID'] + [col for col in blink_analysis_summary.columns if col != 'ParticipantID']
blink_analysis_summary = blink_analysis_summary[cols]
blink_analysis_csv_path = os.path.join(output_dir, 'blink_analysis.csv')
blink_analysis_summary.to_csv(blink_analysis_csv_path, index=False)

print(f'Combined blink analysis CSV file created at: {blink_analysis_csv_path}')
# Out:
# C:\Users\Mobile Workstation 3\AppData\Local\Temp\ipykernel_11340\2113798834.py:68: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = load_data(file_path)
# Blink analysis CSV file created for Participant 10 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant10_2023_12_07_19_13_57_blinks.csv
# Blink analysis CSV file created for Participant 15 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant15_2023_12_11_14_02_52_blinks.csv
# Blink analysis CSV file created for Participant 16 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant16_2023_12_11_16_15_30_blinks.csv
# Blink analysis CSV file created for Participant 20 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant20_2023_12_11_18_20_19_blinks.csv
# Blink analysis CSV file created for Participant 21 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant21_2023_12_12_11_20_59_blinks.csv
# Blink analysis CSV file created for Participant 22 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant22_2023_12_12_15_10_01_blinks.csv
# Blink analysis CSV file created for Participant 23 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant23_2023_12_12_18_01_13_blinks.csv
# Blink analysis CSV file created for Participant 24 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant24_2023_12_13_13_35_48_blinks.csv
# Blink analysis CSV file created for Participant 25 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant25_2023_12_13_18_34_56_blinks.csv
# Blink analysis CSV file created for Participant 26 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant26_2023_12_14_14_28_00_blinks.csv
# Blink analysis CSV file created for Participant 27 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant27_2023_12_14_16_12_49_blinks.csv
# Blink analysis CSV file created for Participant 28 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant28_2023_12_14_17_58_57_blinks.csv
# Blink analysis CSV file created for Participant 29 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant29_2023_12_15_10_17_24_blinks.csv
# Blink analysis CSV file created for Participant 2 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant2_2023_12_07_12_29_23_blinks.csv
# Blink analysis CSV file created for Participant 30 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant30_2023_12_15_13_32_17_blinks.csv
# Blink analysis CSV file created for Participant 31 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant31_2023_12_15_16_05_36_blinks.csv
# Blink analysis CSV file created for Participant 32 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant32_2023_12_18_10_21_54_blinks.csv
# Blink analysis CSV file created for Participant 33 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant33_2023_12_18_12_14_51_blinks.csv
# Blink analysis CSV file created for Participant 34 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant34_2023_12_18_14_09_13_blinks.csv
# Blink analysis CSV file created for Participant 35 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant35_2023_12_18_16_10_31_blinks.csv
# Blink analysis CSV file created for Participant 36 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant36_2023_12_18_18_29_35_blinks.csv
# Blink analysis CSV file created for Participant 37 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant37_2023_12_19_10_01_52_blinks.csv
# Blink analysis CSV file created for Participant 38 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant38_2023_12_19_11_31_47_blinks.csv
# Blink analysis CSV file created for Participant 39 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant39_2023_12_19_14_17_15_blinks.csv
# Blink analysis CSV file created for Participant 3 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant3_2023_12_07_14_37_09_blinks.csv
# Blink analysis CSV file created for Participant 40 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant40_2023_12_19_16_04_39_blinks.csv
# Blink analysis CSV file created for Participant 41 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant41_2023_12_19_18_08_42_blinks.csv
# Blink analysis CSV file created for Participant 44 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant44_2024_01_08_14_32_05_blinks.csv
# Blink analysis CSV file created for Participant 45 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant45_2024_01_09_10_03_25_blinks.csv
# Blink analysis CSV file created for Participant 46 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant46_2024_01_09_14_03_48_blinks.csv
# Blink analysis CSV file created for Participant 47 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant47_2024_01_10_17_39_05_blinks.csv
# Blink analysis CSV file created for Participant 48 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant48_2024_01_11_13_14_50_blinks.csv
# Blink analysis CSV file created for Participant 49 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant49_2024_01_12_10_08_55_blinks.csv
# Blink analysis CSV file created for Participant 4 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant4_2023_12_07_16_52_11_blinks.csv
# Blink analysis CSV file created for Participant 50 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant50_2024_01_12_12_43_28_blinks.csv
# Blink analysis CSV file created for Participant 51 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant51_2024_01_12_17_46_37_blinks.csv
# Blink analysis CSV file created for Participant 52 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant52_2024_01_15_10_40_04_blinks.csv
# Blink analysis CSV file created for Participant 53 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant53_2024_01_15_14_42_54_blinks.csv
# Blink analysis CSV file created for Participant 54 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant54_2024_01_15_17_06_51_blinks.csv
# Blink analysis CSV file created for Participant 56 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant56_2024_01_16_09_57_16_blinks.csv
# Blink analysis CSV file created for Participant 57 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant57_2024_01_16_11_30_34_blinks.csv
# Blink analysis CSV file created for Participant 59 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant59_2024_01_16_13_12_08_blinks.csv
# Blink analysis CSV file created for Participant 60 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant60_2024_01_18_16_07_15_blinks.csv
# Blink analysis CSV file created for Participant 61 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant61_2024_01_19_10_05_34_blinks.csv
# Blink analysis CSV file created for Participant 62 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant62_2024_01_19_15_39_12_blinks.csv
# Blink analysis CSV file created for Participant 65 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant65_2024_01_22_10_44_35_blinks.csv
# Blink analysis CSV file created for Participant 66 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant66_2024_01_22_14_34_48_blinks.csv
# Blink analysis CSV file created for Participant 67 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant67_2024_01_22_17_02_36_blinks.csv
# Blink analysis CSV file created for Participant 68 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant68_2024_01_23_09_32_01_blinks.csv
# Blink analysis CSV file created for Participant 71 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant71_2024_01_23_17_02_55_blinks.csv
# Blink analysis CSV file created for Participant 72 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant72_2024_01_26_10_09_07_blinks.csv
# Blink analysis CSV file created for Participant 73 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant73_2024_01_29_10_36_24_blinks.csv
# Blink analysis CSV file created for Participant 74 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant74_2024_01_30_10_37_48_blinks.csv
# Blink analysis CSV file created for Participant 75 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant75_2024_01_30_12_40_11_blinks.csv
# Blink analysis CSV file created for Participant 76 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant76_2024_01_30_14_34_40_blinks.csv
# Blink analysis CSV file created for Participant 77 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant77_2024_01_30_16_37_18_blinks.csv
# Blink analysis CSV file created for Participant 78 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant78_2024_01_30_18_03_07_blinks.csv
# Blink analysis CSV file created for Participant 79 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant79_2024_01_31_18_03_52_blinks.csv
# Blink analysis CSV file created for Participant 80 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant80_2024_02_02_13_04_47_blinks.csv
# Blink analysis CSV file created for Participant 81 at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\EyeTrackingData_Participant81_2024_02_02_14_11_58_blinks.csv
# Combined blink analysis CSV file created at: C:\Users\Mobile Workstation 3\OneDrive - Queen's University\Coding Scripts\EyeTrackingData\Eye_Tracking_Features\blink_analysis.csv
